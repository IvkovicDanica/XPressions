# %%
import gensim
w2v_model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
w2v_model.most_similar(positive=["sad"])
# Out:
# [('saddening', 0.7273085713386536),
#  ('Sad', 0.6610826849937439),
#  ('saddened', 0.6604382395744324),
#  ('heartbreaking', 0.6573508381843567),
#  ('disheartening', 0.6507317423820496),
#  ('Meny_Friedman', 0.6487058401107788),
#  ('parishioner_Pat_Patello', 0.6475860476493835),
#  ('saddens_me', 0.6407119035720825),
#  ('distressing', 0.6399092674255371),
#  ('reminders_bobbing', 0.6357713341712952)]

# %%
w2v_model.most_similar(positive=["school"])
# Out:
# [('elementary', 0.7868632078170776),
#  ('schools', 0.7411909103393555),
#  ('shool', 0.6692329049110413),
#  ('elementary_schools', 0.6597153544425964),
#  ('kindergarten', 0.6529811024665833),
#  ('eighth_grade', 0.6488089561462402),
#  ('School', 0.6477997303009033),
#  ('teacher', 0.63824063539505),
#  ('students', 0.6301522850990295),
#  ('classroom', 0.6281620264053345)]

# %%
w2v_model.most_similar(positive=["drink"])
# Out:
# [('drinks', 0.8052950501441956),
#  ('drinking', 0.7559558749198914),
#  ('alcoholic_drink', 0.7126703262329102),
#  ('alcoholic_drinks', 0.6724217534065247),
#  ('Drink', 0.666801393032074),
#  ('drank', 0.6666451096534729),
#  ('Drinking', 0.6552879214286804),
#  ('beer', 0.6367323994636536),
#  ('kool_aide', 0.6318148970603943),
#  ('drunk', 0.6291499137878418)]

# %%
w2v_model.get_vector('moral')
# Out:
# array([ 0.37890625, -0.00595093,  0.13476562,  0.3046875 , -0.26367188,
#         0.00390625,  0.36132812,  0.15722656,  0.12109375,  0.11328125,
#        -0.11914062, -0.0098877 ,  0.18261719,  0.32226562, -0.14160156,
#         0.11865234,  0.03466797,  0.10205078, -0.28515625, -0.34960938,
#         0.265625  , -0.34960938,  0.22558594,  0.27539062,  0.25      ,
#        -0.25976562, -0.125     ,  0.265625  ,  0.25390625, -0.06494141,
#         0.109375  , -0.16601562, -0.05493164, -0.02905273, -0.06835938,
#        -0.0279541 ,  0.02270508,  0.28320312,  0.29101562, -0.02697754,
#         0.04931641, -0.02160645,  0.22070312, -0.26757812, -0.05078125,
#         0.03271484, -0.02294922, -0.17382812,  0.00872803, -0.03515625,
#        -0.125     ,  0.3359375 , -0.24902344, -0.15625   ,  0.328125  ,
#        -0.08105469, -0.1796875 , -0.27148438, -0.05249023, -0.1640625 ,
#         0.12109375,  0.26367188,  0.27734375, -0.06396484,  0.02868652,
# ...

# %%
w2v_model.similarity("king", "queen")
# Out:
# 0.6510957

# %%
w2v_model.similarity("man", "woman")
# Out:
# 0.76640123

# %%
w2v_model.similarity("france", "paris")
# Out:
# 0.5550796

# %%
w2v_model.similarity("germany", "berlin")
# Out:
# 0.5539934
